# %%
import pandas as pd
import numpy as np
import os

path = r'C:\Users\howel\OneDrive\Instacart Basket Analysis'

# %%
# Import the pickle file you just saved
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Import the products data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 12)

# %%
# Drop the existing merge column (from the previous notebook)
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# Merge with products
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
